# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("ecommerce_data.csv")
data
# Out:
#      is_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
# 0            1                  0        0.657510                     0
# 1            1                  1        0.568571                     0
# 2            1                  0        0.042246                     1
# 3            1                  1        1.659793                     1
# 4            0                  1        2.014745                     1
# 5            1                  1        0.512447                     1
# 6            0                  0        1.440327                     1
# 7            1                  0        0.035260                     0
# 8            0                  1        1.490764                     0
# 9            0                  0        0.005838                     1
# 10           0                  4        2.046040                     1
# 11           0                  0        0.955889                     0
# ...

# %%
label = ["is_mobile","n_products_viewed","visit_duration","is_returning_visitor","time_of_day","user_action"]

# %%
def getMax(label):
    a = 0
    for i in label:
        if i >= a:
            a = i
    return a

# %%
maxdata = getMax(data["is_mobile"])

# %%
maxdata = getMax(data["is_mobile"])
data["is_mobile"] = data["is_mobile"]/maxdata

# %%
for i in label:
    maxdata = getMax(data[i])
    data[i] = data[i]/maxdata

# %%
data
# Out:
#      is_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
# 0          1.0               0.00        0.103240                   0.0
# 1          1.0               0.25        0.089275                   0.0
# 2          1.0               0.00        0.006633                   1.0
# 3          1.0               0.25        0.260614                   1.0
# 4          0.0               0.25        0.316347                   1.0
# 5          1.0               0.25        0.080462                   1.0
# 6          0.0               0.00        0.226154                   1.0
# 7          1.0               0.00        0.005536                   0.0
# 8          0.0               0.25        0.234074                   0.0
# 9          0.0               0.00        0.000917                   1.0
# 10         0.0               1.00        0.321261                   1.0
# 11         0.0               0.00        0.150090                   0.0
# ...
